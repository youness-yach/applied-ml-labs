# %%
import random
import matplotlib
import matplotlib.pyplot as plt
import time



'''def rollDice(): 
    roll = random.randint(1, 100)

    if roll == 100: 
        #print(roll,'roll was 100, you lose. Play again')
        return False
    elif roll <= 50:
        #print(roll,'roll was 1-50, you lose.')
        return False
    elif 100 > roll > 50: 
        #print(roll,'roll was 51-99, you win!!')
        return True'''

def rollDice(): 
    roll = random.randint(1, 100)

    if roll <= 50:
        #print(roll,'roll was 1-50, you lose.')
        return False
    elif roll >= 51: 
        #print(roll,'roll was 51-99, you win!!')
        return True


def dAlembert(funds, initial_wager, wager_count):
    global ret
    global da_busts
    global da_profits

    value = funds
    wager = initial_wager
    currentWager = 1
    previousWager = 'win'

    previousWagerAmount = initial_wager 

    while currentWager <= wager_count:
        if previousWager == 'win':
            if wager == initial_wager: 
                pass
            else:
                wager -= initial_wager

            #print('current wager', wager, 'value', value)

            if rollDice():
                value += wager
                #print('we won, current value', value)
                previousWagerAmount = wager
            else:
                value -= wager
                previousWager = 'loss'
                #print('we lost, current value', value)
                previousWagerAmount = wager

                if value <= 0:
                    da_busts += 1
                    break

        elif previousWager == 'loss':
            wager = previousWagerAmount + initial_wager
            if(value - wager) <= 0:
                wager = value

            #print('lost last wager', wager, 'value', value)

            if rollDice():
                value += wager
                previousWager = 'win'
                #print('we won, current value', value)
                previousWagerAmount = wager
                
            else:
                value -= wager
                #print('we lost, current value', value)
                previousWagerAmount = wager

                if value <= 0:
                    da_busts += 1
                    break
        
        currentWager += 1

    if value > funds:
        da_profits += 1

    #print(value)

    ret += value


lower_bust = 31.235
higher_profit = 63.208

sampleSize = 100
startingFunds = 10000

while True:
    #wagerSize = 100
    #wagerCount = 1000
    wagerSize = random.uniform(1.0,100.0)
    wagerCount = random.uniform(10.0,1000.0) 
        
    ret = 0.0
    da_busts = 0.0
    da_profits = 0.0
    daSampSize = 100
    counter = 1
    
    wagerSizePercent = (wagerSize/startingFunds)*100.00
    
    while counter <= daSampSize: 
        dAlembert(startingFunds, wagerSize, wagerCount)
        counter += 1
    
    ROI = ret - (daSampSize*startingFunds)
    totalInvested = daSampSize*startingFunds
    
    percentROI = (ROI/totalInvested)*100.00
    
    if percentROI > 1:
        print('------------------------')
        print('total invested', daSampSize*startingFunds)
        print('total return', ret)
        print('ROI', percentROI)
        print('bust rate', (da_busts/daSampSize)*100.00)
        print('profit rate', (da_profits/daSampSize)*100.00)
        print('wager size', wagerSize)
        print('wager count', wagerCount)
        print('wager size percentage', wagerSizePercent)

        saveFile = open('monteCarloLiberal.csv','a') 
        saveLine = '\n'+str(percentROI)+','+str(wagerSizePercent)+','+str(wagerCount)+',g'
        saveFile.write(saveLine)
        saveFile.close()

    elif percentROI < -1:
        print('------------------------')
        print('total invested', daSampSize*startingFunds)
        print('total return', ret)
        print('ROI', percentROI)
        print('bust rate', (da_busts/daSampSize)*100.00)
        print('profit rate', (da_profits/daSampSize)*100.00)
        print('wager size', wagerSize)
        print('wager count', wagerCount)
        print('wager size percentage', wagerSizePercent)

        saveFile = open('monteCarloLiberal.csv','a') 
        saveLine = '\n'+str(percentROI)+','+str(wagerSizePercent)+','+str(wagerCount)+',r'
        saveFile.write(saveLine)
        saveFile.close()
# Out:
# ------------------------
# total invested 1000000
# total return 1111739.7601097592
# ROI 11.173976010975917
# bust rate 44.0
# profit rate 51.0
# wager size 72.14766938519747
# wager count 408.5789839797554
# wager size percentage 0.7214766938519748
# ------------------------
# total invested 1000000
# total return 1044779.638409775
# ROI 4.477963840977498
# bust rate 46.0
# profit rate 49.0
# wager size 54.22620355555589
# wager count 583.0131270944189
# wager size percentage 0.5422620355555589
# ------------------------
# total invested 1000000
# total return 978769.4785030675
# ROI -2.123052149693249
# bust rate 2.0
# profit rate 65.0
# wager size 6.4167909383466295
# wager count 533.241645200287
# wager size percentage 0.0641679093834663
# ------------------------
# total invested 1000000
# total return 915711.7519233563
# ROI -8.428824807664368
# bust rate 43.0
# profit rate 52.0
# wager size 24.797211198431835
# wager count 872.2609943985092
# wager size percentage 0.24797211198431834
# ------------------------
# total invested 1000000
# total return 800879.3549738609
# ROI -19.91206450261391
# bust rate 73.0
# profit rate 26.0
# wager size 98.16010427073542
# wager count 694.3774778607533
# wager size percentage 0.9816010427073542
# ------------------------
# total invested 1000000
# total return 1239237.0343704063
# ROI 23.92370343704063
# bust rate 53.0
# profit rate 44.0
# wager size 54.9539247022759
# wager count 828.2620551420913
# wager size percentage 0.5495392470227589
# ------------------------
# total invested 1000000
# total return 1104022.930929816
# ROI 10.40229309298161
# bust rate 13.0
# profit rate 75.0
# wager size 14.210583783800416
# wager count 718.8136682033851
# wager size percentage 0.14210583783800418
# ------------------------
# total invested 1000000
# total return 1155980.1340451739
# ROI 15.598013404517388
# bust rate 13.0
# profit rate 73.0
# wager size 53.99920019081632
# wager count 212.69464377592791
# wager size percentage 0.5399920019081632
# ------------------------
# total invested 1000000
# total return 1091904.8697100536
# ROI 9.190486971005354
# bust rate 56.00000000000001
# profit rate 37.0
# wager size 89.55476052890947
# wager count 504.17788137396445
# wager size percentage 0.8955476052890947
# ------------------------
# total invested 1000000
# total return 1216677.1098535499
# ROI 21.667710985354987
# bust rate 62.0
# profit rate 38.0
# wager size 81.36286796451103
# wager count 701.449837907004
# wager size percentage 0.8136286796451102
# ------------------------
# total invested 1000000
# total return 696597.5779767375
# ROI -30.340242202326245
# bust rate 70.0
# profit rate 25.0
# wager size 90.45664958050207
# wager count 510.460638453646
# wager size percentage 0.9045664958050207
# ------------------------
# total invested 1000000
# total return 1061272.3336546128
# ROI 6.127233365461277
# bust rate 4.0
# profit rate 73.0
# wager size 6.243714016616522
# wager count 972.6948387048543
# wager size percentage 0.06243714016616523
# ------------------------
# total invested 1000000
# total return 971873.5872284417
# ROI -2.8126412771558273
# bust rate 9.0
# profit rate 56.99999999999999
# wager size 36.013332614030844
# wager count 190.57981363702905
# wager size percentage 0.36013332614030846
# ------------------------
# total invested 1000000
# total return 776555.5072838573
# ROI -22.344449271614266
# bust rate 57.99999999999999
# profit rate 37.0
# wager size 73.22066901235642
# wager count 441.81976156968267
# wager size percentage 0.7322066901235642
# ------------------------
# total invested 1000000
# total return 789686.7457273329
# ROI -21.03132542726671
# bust rate 71.0
# profit rate 28.000000000000004
# wager size 87.7030067405959
# wager count 581.4698752490979
# wager size percentage 0.8770300674059589
# ------------------------
# total invested 1000000
# total return 1056644.584626625
# ROI 5.664458462662506
# bust rate 10.0
# profit rate 71.0
# wager size 48.89628952346363
# wager count 188.45865938231316
# wager size percentage 0.4889628952346363
# ------------------------
# total invested 1000000
# total return 921715.4980235014
# ROI -7.828450197649864
# bust rate 37.0
# profit rate 51.0
# wager size 70.9403265068602
# wager count 254.011956694559
# wager size percentage 0.709403265068602
# ------------------------
# total invested 1000000
# total return 924791.4492085495
# ROI -7.520855079145054
# bust rate 72.0
# profit rate 27.0
# wager size 81.2598888053538
# wager count 916.8051737259759
# wager size percentage 0.812598888053538
# ------------------------
# total invested 1000000
# total return 913400.694583942
# ROI -8.659930541605805
# bust rate 69.0
# profit rate 28.999999999999996
# wager size 97.81544774779707
# wager count 606.7318468485313
# wager size percentage 0.9781544774779707
# ------------------------
# total invested 1000000
# total return 965903.5024296349
# ROI -3.4096497570365085
# bust rate 67.0
# profit rate 32.0
# wager size 89.79439837369797
# wager count 653.8679140569625
# wager size percentage 0.8979439837369797
# ------------------------
# total invested 1000000
# total return 1032688.338102198
# ROI 3.268833810219797
# bust rate 48.0
# profit rate 48.0
# wager size 44.10681806335528
# wager count 699.2455287543886
# wager size percentage 0.44106818063355274
# ------------------------
# total invested 1000000
# total return 1096555.0500695258
# ROI 9.655505006952584
# bust rate 47.0
# profit rate 51.0
# wager size 40.29816296569871
# wager count 795.5295449236316
# wager size percentage 0.40298162965698703
# ------------------------
# total invested 1000000
# total return 892577.7417376874
# ROI -10.742225826231262
# bust rate 76.0
# profit rate 24.0
# wager size 82.2965165791194
# wager count 929.4418105023526
# wager size percentage 0.8229651657911939
# ------------------------
# total invested 1000000
# total return 1181254.4264817485
# ROI 18.125442648174847
# bust rate 54.0
# profit rate 43.0
# wager size 86.07637176255895
# wager count 557.9229933464377
# wager size percentage 0.8607637176255895
# ------------------------
# total invested 1000000
# total return 1015539.9139198676
# ROI 1.5539913919867598
# bust rate 0.0
# profit rate 69.0
# wager size 19.23256673250925
# wager count 93.88158981086113
# wager size percentage 0.19232566732509251
# ------------------------
# total invested 1000000
# total return 951153.491322515
# ROI -4.884650867748505
# bust rate 4.0
# profit rate 60.0
# wager size 62.74119629421981
# wager count 53.48713234375558
# wager size percentage 0.6274119629421981
# ------------------------
# total invested 1000000
# total return 851029.3040566411
# ROI -14.897069594335893
# bust rate 43.0
# profit rate 44.0
# wager size 23.370108328389627
# wager count 878.523678516423
# wager size percentage 0.23370108328389627
# ------------------------
# total invested 1000000
# total return 804271.1238433447
# ROI -19.572887615665525
# bust rate 60.0
# profit rate 37.0
# wager size 59.962705224136315
# wager count 557.8621911700396
# wager size percentage 0.5996270522413631
# ------------------------
# total invested 1000000
# total return 1029812.5007839228
# ROI 2.981250078392285
# bust rate 35.0
# profit rate 57.99999999999999
# wager size 46.94976451637828
# wager count 402.45862283869735
# wager size percentage 0.4694976451637828
# ------------------------
# total invested 1000000
# total return 955267.3570980246
# ROI -4.473264290197543
# bust rate 53.0
# profit rate 41.0
# wager size 56.23830056550395
# wager count 590.7717924273204
# wager size percentage 0.5623830056550395
# ------------------------
# total invested 1000000
# total return 1028476.7022835487
# ROI 2.8476702283548656
# bust rate 30.0
# profit rate 60.0
# wager size 16.78678202700482
# wager count 886.0526617108719
# wager size percentage 0.16786782027004818
# ------------------------
# total invested 1000000
# total return 1012011.2428801327
# ROI 1.2011242880132749
# bust rate 50.0
# profit rate 42.0
# wager size 90.78214801157509
# wager count 402.37203511718064
# wager size percentage 0.9078214801157509
# ------------------------
# total invested 1000000
# total return 1058007.1377661007
# ROI 5.80071377661007
# bust rate 26.0
# profit rate 64.0
# wager size 25.75277486077756
# wager count 624.0369911474262
# wager size percentage 0.2575277486077756
# ------------------------
# total invested 1000000
# total return 1234469.5553086535
# ROI 23.446955530865353
# bust rate 49.0
# profit rate 48.0
# wager size 35.99536936427759
# wager count 971.5395583646391
# wager size percentage 0.35995369364277596
# ------------------------
# total invested 1000000
# total return 1123599.5793742014
# ROI 12.359957937420136
# bust rate 53.0
# profit rate 45.0
# wager size 80.20096490433225
# wager count 514.6845435236971
# wager size percentage 0.8020096490433224
# ------------------------
# total invested 1000000
# total return 1093904.105086421
# ROI 9.39041050864209
# bust rate 57.99999999999999
# profit rate 39.0
# wager size 90.055472384435
# wager count 530.2875678311152
# wager size percentage 0.90055472384435
# ------------------------
# total invested 1000000
# total return 1039487.1925557521
# ROI 3.9487192555752113
# bust rate 39.0
# profit rate 50.0
# wager size 59.848268547678266
# wager count 491.5475568978879
# wager size percentage 0.5984826854767826
# ------------------------
# total invested 1000000
# total return 1059971.5881840496
# ROI 5.997158818404959
# bust rate 34.0
# profit rate 56.99999999999999
# wager size 28.9010271514444
# wager count 747.4347915435322
# wager size percentage 0.28901027151444403
# ------------------------
# total invested 1000000
# total return 1171999.794181207
# ROI 17.199979418120694
# bust rate 51.0
# profit rate 46.0
# wager size 63.20588220946389
# wager count 725.674328575855
# wager size percentage 0.6320588220946389
# ------------------------
# total invested 1000000
# total return 989851.0199422587
# ROI -1.0148980057741281
# bust rate 74.0
# profit rate 26.0
# wager size 89.26390807117333
# wager count 975.6178343038582
# wager size percentage 0.8926390807117334
# ------------------------
# total invested 1000000
# total return 837627.1736936138
# ROI -16.237282630638617
# bust rate 71.0
# profit rate 26.0
# wager size 94.31546687994741
# wager count 716.0398634478795
# wager size percentage 0.943154668799474
# ------------------------
# total invested 1000000
# total return 1041117.153660003
# ROI 4.111715366000298
# bust rate 41.0
# profit rate 53.0
# wager size 42.823791029621944
# wager count 630.3660178563305
# wager size percentage 0.42823791029621944
# ------------------------
# total invested 1000000
# total return 1190541.4632664893
# ROI 19.054146326648933
# bust rate 32.0
# profit rate 62.0
# wager size 56.03775930006402
# wager count 406.8671682740963
# wager size percentage 0.5603775930006402
# ------------------------
# total invested 1000000
# total return 758546.1084005284
# ROI -24.145389159947158
# bust rate 77.0
# profit rate 23.0
# wager size 74.75451199292993
# wager count 880.0701692565668
# wager size percentage 0.7475451199292994
# ------------------------
# total invested 1000000
# total return 981162.339882829
# ROI -1.8837660117171005
# bust rate 6.0
# profit rate 68.0
# wager size 28.536941284641834
# wager count 168.51215155258674
# wager size percentage 0.2853694128464183
# ------------------------
# total invested 1000000
# total return 1071186.7354792862
# ROI 7.1186735479286165
# bust rate 49.0
# profit rate 47.0
# wager size 48.29868232746856
# wager count 744.4443035031687
# wager size percentage 0.48298682327468556
# ------------------------
# total invested 1000000
# total return 978824.0182488883
# ROI -2.1175981751111688
# bust rate 32.0
# profit rate 56.99999999999999
# wager size 79.58232402777757
# wager count 205.40677724253675
# wager size percentage 0.7958232402777758
# ------------------------
# total invested 1000000
# total return 1122670.521095596
# ROI 12.267052109559602
# bust rate 51.0
# profit rate 46.0
# wager size 88.5020895112756
# wager count 441.3504247287922
# wager size percentage 0.8850208951127561
# ------------------------
# total invested 1000000
# total return 1071994.4665109722
# ROI 7.199446651097224
# bust rate 51.0
# profit rate 44.0
# wager size 90.91941319199272
# wager count 429.231643016962
# wager size percentage 0.9091941319199273
# ------------------------
# total invested 1000000
# total return 985894.0270737348
# ROI -1.4105972926265211
# bust rate 6.0
# profit rate 66.0
# wager size 16.326944802589566
# wager count 345.03882427264324
# wager size percentage 0.16326944802589566
# ------------------------
# total invested 1000000
# total return 713734.7136667209
# ROI -28.626528633327908
# bust rate 72.0
# profit rate 26.0
# wager size 57.127030819229184
# wager count 981.9258902086679
# wager size percentage 0.5712703081922919
# ------------------------
# total invested 1000000
# total return 1038276.4150368405
# ROI 3.827641503684048
# bust rate 53.0
# profit rate 46.0
# wager size 35.543645046848226
# wager count 836.0225383565919
# wager size percentage 0.35543645046848227
# ------------------------
# total invested 1000000
# total return 1149377.8105622684
# ROI 14.937781056226838
# bust rate 23.0
# profit rate 64.0
# wager size 28.440911459842862
# wager count 657.9212373295944
# wager size percentage 0.2844091145984286
# ------------------------
# total invested 1000000
# total return 1019659.6064042033
# ROI 1.965960640420334
# bust rate 39.0
# profit rate 51.0
# wager size 80.85681727537215
# wager count 280.0063469031456
# wager size percentage 0.8085681727537215
# ------------------------
# total invested 1000000
# total return 971691.3537466236
# ROI -2.8308646253376386
# bust rate 2.0
# profit rate 61.0
# wager size 5.84007854972135
# wager count 728.8710738478791
# wager size percentage 0.05840078549721351
# ------------------------
# total invested 1000000
# total return 954294.2361019448
# ROI -4.5705763898055185
# bust rate 56.99999999999999
# profit rate 39.0
# wager size 52.67950858390863
# wager count 796.5758190018145
# wager size percentage 0.5267950858390863
# ------------------------
# total invested 1000000
# total return 946708.1547246848
# ROI -5.329184527531523
# bust rate 32.0
# profit rate 53.0
# wager size 60.407947580064814
# wager count 299.35932759366403
# wager size percentage 0.6040794758006481
# ------------------------
# total invested 1000000
# total return 1020378.3386597098
# ROI 2.0378338659709785
# bust rate 16.0
# profit rate 68.0
# wager size 79.46594270932876
# wager count 155.69133693418846
# wager size percentage 0.7946594270932876
# ------------------------
# total invested 1000000
# total return 950448.3068284302
# ROI -4.955169317156984
# bust rate 75.0
# profit rate 24.0
# wager size 86.85101555808954
# wager count 907.8224671803979
# wager size percentage 0.8685101555808955
# ------------------------
# total invested 1000000
# total return 910382.8436016828
# ROI -8.961715639831718
# bust rate 41.0
# profit rate 54.0
# wager size 38.677122583838624
# wager count 457.29833454650964
# wager size percentage 0.38677122583838625
# ------------------------
# total invested 1000000
# total return 1053298.281365067
# ROI 5.3298281365067
# bust rate 6.0
# profit rate 72.0
# wager size 6.228220412448745
# wager count 956.3157190724104
# wager size percentage 0.06228220412448745
# ------------------------
# total invested 1000000
# total return 1112349.9844137698
# ROI 11.23499844137698
# bust rate 51.0
# profit rate 46.0
# wager size 61.45765862964228
# wager count 586.1177637061236
# wager size percentage 0.6145765862964228
# ------------------------
# total invested 1000000
# total return 1018384.9564828621
# ROI 1.8384956482862123
# bust rate 65.0
# profit rate 33.0
# wager size 73.32078215134
# wager count 769.1249256604816
# wager size percentage 0.7332078215133999
# ------------------------
# total invested 1000000
# total return 972575.2485726007
# ROI -2.7424751427399343
# bust rate 22.0
# profit rate 61.0
# wager size 25.81192948926015
# wager count 454.6322958934114
# wager size percentage 0.2581192948926015
# ------------------------
# total invested 1000000
# total return 1077826.945946138
# ROI 7.782694594613789
# bust rate 45.0
# profit rate 53.0
# wager size 63.903657059310994
# wager count 495.4948192844384
# wager size percentage 0.6390365705931099
# ------------------------
# total invested 1000000
# total return 970365.9490734895
# ROI -2.963405092651048
# bust rate 13.0
# profit rate 63.0
# wager size 22.168912623389478
# wager count 317.5978623201289
# wager size percentage 0.22168912623389478
# ------------------------
# total invested 1000000
# total return 1052033.5962629963
# ROI 5.2033596262996324
# bust rate 50.0
# profit rate 49.0
# wager size 49.466849119331975
# wager count 645.9237921405212
# wager size percentage 0.49466849119331974
# ------------------------
# total invested 1000000
# total return 1096683.5906381502
# ROI 9.668359063815023
# bust rate 7.000000000000001
# profit rate 79.0
# wager size 84.45329365435032
# wager count 87.80163632408473
# wager size percentage 0.8445329365435033
# ------------------------
# total invested 1000000
# total return 924151.2077575984
# ROI -7.584879224240162
# bust rate 42.0
# profit rate 49.0
# wager size 33.98167604126206
# wager count 577.6153024063631
# wager size percentage 0.3398167604126206
# ------------------------
# total invested 1000000
# total return 908754.8303715297
# ROI -9.124516962847032
# bust rate 46.0
# profit rate 52.0
# wager size 78.7815586705047
# wager count 257.06543172080853
# wager size percentage 0.7878155867050469
# ------------------------
# total invested 1000000
# total return 938024.7932123875
# ROI -6.1975206787612525
# bust rate 28.000000000000004
# profit rate 57.99999999999999
# wager size 18.92902544166561
# wager count 645.831568407261
# wager size percentage 0.1892902544166561
# ------------------------
# total invested 1000000
# total return 933240.8836938187
# ROI -6.675911630618129
# bust rate 40.0
# profit rate 56.00000000000001
# wager size 71.240680641949
# wager count 269.49162591393304
# wager size percentage 0.7124068064194901
# ------------------------
# total invested 1000000
# total return 988420.5286466653
# ROI -1.1579471353334723
# bust rate 0.0
# profit rate 66.0
# wager size 3.8279244143254845
# wager count 260.10468972515577
# wager size percentage 0.03827924414325485
# ------------------------
# total invested 1000000
# total return 1011504.6794588998
# ROI 1.1504679458899774
# bust rate 0.0
# profit rate 69.0
# wager size 61.19510350478983
# wager count 30.482618655676706
# wager size percentage 0.6119510350478983
# ------------------------
# total invested 1000000
# total return 973966.4779886092
# ROI -2.603352201139077
# bust rate 73.0
# profit rate 27.0
# wager size 71.75164217442256
# wager count 850.086735019353
# wager size percentage 0.7175164217442256
# ------------------------
# total invested 1000000
# total return 962654.4333790408
# ROI -3.7345566620959203
# bust rate 40.0
# profit rate 53.0
# wager size 21.596218664480777
# wager count 861.4421202953004
# wager size percentage 0.2159621866448078
# ------------------------
# total invested 1000000
# total return 987116.8621033335
# ROI -1.2883137896666534
# bust rate 0.0
# profit rate 62.0
# wager size 3.392978113422852
# wager count 508.35132066440264
# wager size percentage 0.03392978113422852
# ------------------------
# total invested 1000000
# total return 795988.4035759405
# ROI -20.401159642405947
# bust rate 69.0
# profit rate 28.999999999999996
# wager size 42.85733954332926
# wager count 972.2088203423225
# wager size percentage 0.4285733954332926
# ------------------------
# total invested 1000000
# total return 1056415.612215439
# ROI 5.641561221543909
# bust rate 9.0
# profit rate 72.0
# wager size 70.43147592439347
# wager count 120.35873533234984
# wager size percentage 0.7043147592439346
# ------------------------
# total invested 1000000
# total return 1012747.1674906118
# ROI 1.2747167490611784
# bust rate 1.0
# profit rate 71.0
# wager size 99.76827846759114
# wager count 30.235328543233738
# wager size percentage 0.9976827846759115
# ------------------------
# total invested 1000000
# total return 1059384.6310568391
# ROI 5.938463105683914
# bust rate 25.0
# profit rate 62.0
# wager size 23.44253703242324
# wager count 655.8534315456909
# wager size percentage 0.23442537032423238
# ------------------------
# total invested 1000000
# total return 942662.7041101615
# ROI -5.733729588983849
# bust rate 39.0
# profit rate 51.0
# wager size 83.8819943403378
# wager count 234.50681879793112
# wager size percentage 0.8388199434033781
# ------------------------
# total invested 1000000
# total return 1190717.5559998923
# ROI 19.071755599989228
# bust rate 48.0
# profit rate 50.0
# wager size 53.01266352064812
# wager count 686.1092579762204
# wager size percentage 0.5301266352064812
# ------------------------
# total invested 1000000
# total return 1170314.9274243591
# ROI 17.031492742435912
# bust rate 48.0
# profit rate 49.0
# wager size 72.68615176466388
# wager count 493.49518635903866
# wager size percentage 0.7268615176466388
# ------------------------
# total invested 1000000
# total return 954044.695260937
# ROI -4.595530473906302
# bust rate 61.0
# profit rate 36.0
# wager size 92.24185746524239
# wager count 568.6370052585706
# wager size percentage 0.9224185746524239
# ------------------------
# total invested 1000000
# total return 1090300.3918558506
# ROI 9.030039185585057
# bust rate 17.0
# profit rate 67.0
# wager size 74.32296543816346
# wager count 167.06175362821423
# wager size percentage 0.7432296543816347
# ------------------------
# total invested 1000000
# total return 912583.2668070013
# ROI -8.741673319299869
# bust rate 75.0
# profit rate 25.0
# wager size 98.10345739476209
# wager count 847.1041725945825
# wager size percentage 0.981034573947621
# ------------------------
# total invested 1000000
# total return 884538.3410594644
# ROI -11.546165894053562
# bust rate 68.0
# profit rate 30.0
# wager size 90.62794603182869
# wager count 639.5712294456613
# wager size percentage 0.9062794603182869
# ------------------------
# total invested 1000000
# total return 644405.1127287449
# ROI -35.55948872712552
# bust rate 77.0
# profit rate 21.0
# wager size 81.05987013101347
# wager count 688.9083484392577
# wager size percentage 0.8105987013101347
# ------------------------
# total invested 1000000
# total return 1020028.7656372128
# ROI 2.002876563721278
# bust rate 0.0
# profit rate 69.0
# wager size 5.14085360298062
# wager count 476.6679114930124
# wager size percentage 0.0514085360298062
# ------------------------
# total invested 1000000
# total return 1084684.6415507933
# ROI 8.468464155079332
# bust rate 32.0
# profit rate 56.99999999999999
# wager size 55.03409720456193
# wager count 342.00124117149505
# wager size percentage 0.5503409720456193
# ------------------------
# total invested 1000000
# total return 989260.3316730376
# ROI -1.073966832696239
# bust rate 75.0
# profit rate 25.0
# wager size 81.18744012240582
# wager count 998.2478729209103
# wager size percentage 0.8118744012240583
# ------------------------
# total invested 1000000
# total return 967120.6978350825
# ROI -3.287930216491746
# bust rate 6.0
# profit rate 59.0
# wager size 8.4672096118115
# wager count 524.4437144069789
# wager size percentage 0.084672096118115
# ------------------------
# total invested 1000000
# total return 790705.63478999
# ROI -20.929436521000998
# bust rate 62.0
# profit rate 35.0
# wager size 51.01703153395409
# wager count 710.9459447314525
# wager size percentage 0.5101703153395409
# ------------------------
# total invested 1000000
# total return 843036.8236816723
# ROI -15.696317631832764
# bust rate 49.0
# profit rate 45.0
# wager size 39.477564155677584
# wager count 540.2776157250333
# wager size percentage 0.39477564155677586
# ------------------------
# total invested 1000000
# total return 1029526.012540732
# ROI 2.9526012540732043
# bust rate 1.0
# profit rate 64.0
# wager size 6.850262138775009
# wager count 590.9283817991206
# wager size percentage 0.0685026213877501
# ------------------------
# total invested 1000000
# total return 946888.2037319608
# ROI -5.311179626803915
# bust rate 6.0
# profit rate 63.0
# wager size 12.858662264626256
# wager count 381.8781891050936
# wager size percentage 0.12858662264626256
# ------------------------
# total invested 1000000
# total return 1152300.1474581491
# ROI 15.230014745814913
# bust rate 59.0
# profit rate 38.0
# wager size 73.39383157451246
# wager count 764.4484052654586
# wager size percentage 0.7339383157451246
# ------------------------
# total invested 1000000
# total return 1045112.2347963549
# ROI 4.51122347963549
# bust rate 63.0
# profit rate 37.0
# wager size 89.57141409788359
# wager count 611.79269071752
# wager size percentage 0.895714140978836
# ------------------------
# total invested 1000000
# total return 873451.1164379617
# ROI -12.65488835620383
# bust rate 51.0
# profit rate 45.0
# wager size 77.87094637349294
# wager count 362.8613452619288
# wager size percentage 0.7787094637349294
# ------------------------
# total invested 1000000
# total return 956461.0641329328
# ROI -4.35389358670672
# bust rate 64.0
# profit rate 35.0
# wager size 53.24846784652841
# wager count 995.5550959018683
# wager size percentage 0.5324846784652841
# ------------------------
# total invested 1000000
# total return 1012467.3394256063
# ROI 1.2467339425606305
# bust rate 51.0
# profit rate 42.0
# wager size 79.93804825485742
# wager count 468.82381300933525
# wager size percentage 0.7993804825485742
# ------------------------
# total invested 1000000
# total return 1360834.7629182981
# ROI 36.08347629182981
# bust rate 47.0
# profit rate 53.0
# wager size 63.747549969018166
# wager count 675.141988948305
# wager size percentage 0.6374754996901817
# ------------------------
# total invested 1000000
# total return 1053758.7444396894
# ROI 5.375874443968944
# bust rate 41.0
# profit rate 52.0
# wager size 82.35449363549739
# wager count 301.5327168472812
# wager size percentage 0.8235449363549739
# ------------------------
# total invested 1000000
# total return 988918.6886701535
# ROI -1.1081311329846502
# bust rate 18.0
# profit rate 64.0
# wager size 60.31139973156857
# wager count 179.13187444622503
# wager size percentage 0.6031139973156857
# ------------------------
# total invested 1000000
# total return 1013107.2483204465
# ROI 1.3107248320446467
# bust rate 45.0
# profit rate 48.0
# wager size 40.86477315418095
# wager count 617.2577198901314
# wager size percentage 0.4086477315418095
# ------------------------
# total invested 1000000
# total return 1071548.8937765812
# ROI 7.154889377658116
# bust rate 68.0
# profit rate 31.0
# wager size 89.04872645290115
# wager count 717.4444778043664
# wager size percentage 0.8904872645290114
# ------------------------
# total invested 1000000
# total return 1064092.3439022996
# ROI 6.409234390229964
# bust rate 4.0
# profit rate 71.0
# wager size 9.466248834283233
# wager count 758.626893859778
# wager size percentage 0.09466248834283233
# ------------------------
# total invested 1000000
# total return 941707.3723201987
# ROI -5.829262767980131
# bust rate 46.0
# profit rate 48.0
# wager size 96.39450970443384
# wager count 285.73741716444715
# wager size percentage 0.9639450970443384
# ------------------------
# total invested 1000000
# total return 790951.2455119605
# ROI -20.904875448803953
# bust rate 71.0
# profit rate 27.0
# wager size 67.04543296184272
# wager count 751.4952070732033
# wager size percentage 0.6704543296184272
# ------------------------
# total invested 1000000
# total return 927782.3189413423
# ROI -7.221768105865771
# bust rate 46.0
# profit rate 47.0
# wager size 28.342970800892576
# wager count 977.3810573574086
# wager size percentage 0.28342970800892575
# ------------------------
# total invested 1000000
# total return 1100385.9808841732
# ROI 10.03859808841732
# bust rate 71.0
# profit rate 28.000000000000004
# wager size 95.51501171735114
# wager count 958.7204466235921
# wager size percentage 0.9551501171735114
# ------------------------
# total invested 1000000
# total return 1272284.571115016
# ROI 27.2284571115016
# bust rate 57.99999999999999
# profit rate 40.0
# wager size 66.32086517219142
# wager count 873.7933881841255
# wager size percentage 0.6632086517219142
# ------------------------
# total invested 1000000
# total return 955330.2382740167
# ROI -4.4669761725983355
# bust rate 60.0
# profit rate 37.0
# wager size 81.24494576594066
# wager count 497.07570136223376
# wager size percentage 0.8124494576594066
# ------------------------
# total invested 1000000
# total return 956408.7351566569
# ROI -4.359126484334306
# bust rate 49.0
# profit rate 46.0
# wager size 31.899117834132504
# wager count 841.3002737404577
# wager size percentage 0.318991178341325
# ------------------------
# total invested 1000000
# total return 926584.9119325553
# ROI -7.341508806744473
# bust rate 15.0
# profit rate 61.0
# wager size 24.914900856464907
# wager count 284.4521270225277
# wager size percentage 0.24914900856464905
# ------------------------
# total invested 1000000
# total return 980202.3553540477
# ROI -1.979764464595227
# bust rate 18.0
# profit rate 65.0
# wager size 77.17251775493547
# wager count 134.0521975624114
# wager size percentage 0.7717251775493547
# ------------------------
# total invested 1000000
# total return 1069447.069928535
# ROI 6.944706992853503
# bust rate 40.0
# profit rate 55.00000000000001
# wager size 81.6544970470539
# wager count 304.9879733482664
# wager size percentage 0.816544970470539
# ------------------------
# total invested 1000000
# total return 1032177.568154882
# ROI 3.2177568154882055
# bust rate 2.0
# profit rate 74.0
# wager size 34.50897364740847
# wager count 119.79420472728674
# wager size percentage 0.34508973647408464
# ------------------------
# total invested 1000000
# total return 1053898.6838361863
# ROI 5.38986838361863
# bust rate 36.0
# profit rate 57.99999999999999
# wager size 56.159499902025516
# wager count 355.4666334572542
# wager size percentage 0.5615949990202551
# ------------------------
# total invested 1000000
# total return 959849.1288284399
# ROI -4.015087117156014
# bust rate 45.0
# profit rate 50.0
# wager size 41.88045794235368
# wager count 639.9913347585543
# wager size percentage 0.4188045794235368
# ------------------------
# total invested 1000000
# total return 913191.6079980042
# ROI -8.680839200199582
# bust rate 66.0
# profit rate 28.000000000000004
# wager size 82.75436511054956
# wager count 720.1891588570942
# wager size percentage 0.8275436511054955
# ------------------------
# total invested 1000000
# total return 958064.4818473866
# ROI -4.193551815261342
# bust rate 60.0
# profit rate 36.0
# wager size 97.83211600502743
# wager count 479.2395628732179
# wager size percentage 0.9783211600502743
# ------------------------
# total invested 1000000
# total return 944941.2430782942
# ROI -5.505875692170579
# bust rate 21.0
# profit rate 57.99999999999999
# wager size 34.52692003783979
# wager count 284.76755900945824
# wager size percentage 0.34526920037839787
# ------------------------
# total invested 1000000
# total return 1197486.0077782802
# ROI 19.748600777828017
# bust rate 44.0
# profit rate 48.0
# wager size 79.04932986377833
# wager count 443.97353757502657
# wager size percentage 0.7904932986377832
# ------------------------
# total invested 1000000
# total return 878835.3897538414
# ROI -12.116461024615855
# bust rate 59.0
# profit rate 39.0
# wager size 36.21958620430537
# wager count 880.8366907774657
# wager size percentage 0.3621958620430537
# ------------------------
# total invested 1000000
# total return 1034653.074794508
# ROI 3.465307479450805
# bust rate 20.0
# profit rate 62.0
# wager size 76.31765188840096
# wager count 193.37754655280094
# wager size percentage 0.7631765188840096
# ------------------------
# total invested 1000000
# total return 1012152.0579470304
# ROI 1.2152057947030408
# bust rate 7.000000000000001
# profit rate 69.0
# wager size 59.651313445325776
# wager count 120.29777722006237
# wager size percentage 0.5965131344532577
# ------------------------
# total invested 1000000
# total return 1066798.3920553438
# ROI 6.679839205534384
# bust rate 70.0
# profit rate 28.000000000000004
# wager size 86.82967708867358
# wager count 838.3924929163556
# wager size percentage 0.8682967708867357
# ------------------------
# total invested 1000000
# total return 1160631.8319171849
# ROI 16.063183191718487
# bust rate 36.0
# profit rate 56.99999999999999
# wager size 40.07520575344448
# wager count 600.342872408863
# wager size percentage 0.4007520575344448
# ------------------------
# total invested 1000000
# total return 948011.0009491799
# ROI -5.198899905082013
# bust rate 61.0
# profit rate 37.0
# wager size 53.47962290811688
# wager count 820.9616757912116
# wager size percentage 0.5347962290811688
# ------------------------
# total invested 1000000
# total return 1025059.7287826637
# ROI 2.5059728782663706
# bust rate 0.0
# profit rate 73.0
# wager size 28.722507077536736
# wager count 112.49720289712201
# wager size percentage 0.28722507077536735
# ------------------------
# total invested 1000000
# total return 1010355.06795934
# ROI 1.0355067959340056
# bust rate 0.0
# profit rate 73.0
# wager size 3.8042130636811633
# wager count 281.3739940898512
# wager size percentage 0.03804213063681164
# ------------------------
# total invested 1000000
# total return 1137010.483274374
# ROI 13.701048327437393
# bust rate 42.0
# profit rate 52.0
# wager size 48.59246457430451
# wager count 656.5622448814389
# wager size percentage 0.48592464574304506
# ------------------------
# total invested 1000000
# total return 968370.1671870027
# ROI -3.1629832812997276
# bust rate 13.0
# profit rate 66.0
# wager size 9.388029526223121
# wager count 728.453222010166
# wager size percentage 0.09388029526223121
# ------------------------
# total invested 1000000
# total return 877153.3164485507
# ROI -12.284668355144932
# bust rate 62.0
# profit rate 33.0
# wager size 88.08651748599706
# wager count 554.276275831823
# wager size percentage 0.8808651748599707
# ------------------------
# total invested 1000000
# total return 937458.0515422255
# ROI -6.254194845777447
# bust rate 20.0
# profit rate 61.0
# wager size 87.82725142883228
# wager count 113.07565255343016
# wager size percentage 0.8782725142883228
# ------------------------
# total invested 1000000
# total return 1176866.0971799039
# ROI 17.686609717990386
# bust rate 60.0
# profit rate 40.0
# wager size 72.50534690794827
# wager count 848.5830726015483
# wager size percentage 0.7250534690794826
# ------------------------
# total invested 1000000
# total return 885756.0941202263
# ROI -11.424390587977367
# bust rate 49.0
# profit rate 48.0
# wager size 50.7932355898215
# wager count 520.4380445639654
# wager size percentage 0.507932355898215
# ------------------------
# total invested 1000000
# total return 1068554.2206707033
# ROI 6.855422067070334
# bust rate 33.0
# profit rate 56.00000000000001
# wager size 40.65314672333575
# wager count 478.02759063704144
# wager size percentage 0.40653146723335754
# ------------------------
# total invested 1000000
# total return 975903.8889068993
# ROI -2.4096111093100743
# bust rate 1.0
# profit rate 65.0
# wager size 7.511256575156117
# wager count 340.34109100462274
# wager size percentage 0.07511256575156117
# ------------------------
# total invested 1000000
# total return 1059505.959810913
# ROI 5.950595981091308
# bust rate 35.0
# profit rate 56.99999999999999
# wager size 82.34003151451569
# wager count 254.29460856796763
# wager size percentage 0.8234003151451569
# ------------------------
# total invested 1000000
# total return 893197.7089253722
# ROI -10.680229107462779
# bust rate 35.0
# profit rate 53.0
# wager size 17.33195719258408
# wager count 932.8480975229793
# wager size percentage 0.17331957192584083
# ------------------------
# total invested 1000000
# total return 958875.4004117782
# ROI -4.112459958822176
# bust rate 21.0
# profit rate 62.0
# wager size 41.141861267431636
# wager count 253.50885794202605
# wager size percentage 0.41141861267431634
# ------------------------
# total invested 1000000
# total return 1041996.6222242477
# ROI 4.199662222424767
# bust rate 5.0
# profit rate 73.0
# wager size 62.50239898846064
# wager count 98.7992085523115
# wager size percentage 0.6250239898846064
# ------------------------
# total invested 1000000
# total return 1085222.9781927643
# ROI 8.522297819276433
# bust rate 26.0
# profit rate 66.0
# wager size 64.8383367555407
# wager count 242.08469601430613
# wager size percentage 0.6483833675554069
# ------------------------
# total invested 1000000
# total return 924862.6714154653
# ROI -7.51373285845347
# bust rate 46.0
# profit rate 47.0
# wager size 31.82643557712094
# wager count 778.1235602056101
# wager size percentage 0.31826435577120943
# ------------------------
# total invested 1000000
# total return 963021.1479297543
# ROI -3.697885207024566
# bust rate 3.0
# profit rate 65.0
# wager size 62.41473282978138
# wager count 62.48288427737488
# wager size percentage 0.6241473282978137
# ------------------------
# total invested 1000000
# total return 986131.9796637709
# ROI -1.386802033622912
# bust rate 74.0
# profit rate 24.0
# wager size 92.42271104692617
# wager count 943.2611029310375
# wager size percentage 0.9242271104692618
# ------------------------
# total invested 1000000
# total return 1032633.0907879993
# ROI 3.263309078799933
# bust rate 49.0
# profit rate 46.0
# wager size 32.83667853505911
# wager count 954.8228899607972
# wager size percentage 0.32836678535059105
# ------------------------
# total invested 1000000
# total return 1076753.8926550017
# ROI 7.675389265500172
# bust rate 10.0
# profit rate 74.0
# wager size 46.29191896819064
# wager count 205.22531798276268
# wager size percentage 0.4629191896819065
# ------------------------
# total invested 1000000
# total return 846516.2102388308
# ROI -15.348378976116923
# bust rate 42.0
# profit rate 49.0
# wager size 68.27642214723735
# wager count 221.71570408320443
# wager size percentage 0.6827642214723736
# ------------------------
# total invested 1000000
# total return 981119.6132958855
# ROI -1.8880386704114498
# bust rate 42.0
# profit rate 52.0
# wager size 34.267047341632406
# wager count 662.7714986239032
# wager size percentage 0.34267047341632406
# ------------------------
# total invested 1000000
# total return 1084564.5457298697
# ROI 8.456454572986974
# bust rate 35.0
# profit rate 57.99999999999999
# wager size 24.706609042684256
# wager count 949.9732992312665
# wager size percentage 0.24706609042684258
# ------------------------
# total invested 1000000
# total return 913100.0161118619
# ROI -8.689998388813809
# bust rate 47.0
# profit rate 47.0
# wager size 27.746850649126706
# wager count 923.0662221165921
# wager size percentage 0.27746850649126703
# ------------------------
# total invested 1000000
# total return 1031173.0866128621
# ROI 3.117308661286207
# bust rate 49.0
# profit rate 47.0
# wager size 59.3114623123075
# wager count 599.9175247786271
# wager size percentage 0.593114623123075
# ------------------------
# total invested 1000000
# total return 967069.5811880856
# ROI -3.2930418811914395
# bust rate 6.0
# profit rate 60.0
# wager size 9.337558188370398
# wager count 448.4968097280454
# wager size percentage 0.09337558188370398
# ------------------------
# total invested 1000000
# total return 1080496.9647769742
# ROI 8.049696477697417
# bust rate 71.0
# profit rate 28.999999999999996
# wager size 93.58780374909298
# wager count 853.6816423486115
# wager size percentage 0.9358780374909299
# ------------------------
# total invested 1000000
# total return 955295.5512954644
# ROI -4.47044487045356
# bust rate 40.0
# profit rate 49.0
# wager size 92.33962368439445
# wager count 244.03611317166158
# wager size percentage 0.9233962368439446
# ------------------------
# total invested 1000000
# total return 1046682.067913073
# ROI 4.6682067913073
# bust rate 4.0
# profit rate 77.0
# wager size 14.023955332967645
# wager count 306.66842130593875
# wager size percentage 0.14023955332967644
# ------------------------
# total invested 1000000
# total return 978871.8645231925
# ROI -2.1128135476807484
# bust rate 1.0
# profit rate 59.0
# wager size 10.043443571126122
# wager count 259.55692925590836
# wager size percentage 0.10043443571126122
# ------------------------
# total invested 1000000
# total return 1057176.197069382
# ROI 5.717619706938206
# bust rate 8.0
# profit rate 74.0
# wager size 93.69958816214644
# wager count 80.88359670688904
# wager size percentage 0.9369958816214644
# ------------------------
# total invested 1000000
# total return 1064486.3275139662
# ROI 6.448632751396624
# bust rate 55.00000000000001
# profit rate 39.0
# wager size 98.75251790340957
# wager count 445.2138665945753
# wager size percentage 0.9875251790340958
# ------------------------
# total invested 1000000
# total return 1032599.6013188184
# ROI 3.25996013188184
# bust rate 18.0
# profit rate 65.0
# wager size 59.27163023959092
# wager count 202.79019341105422
# wager size percentage 0.5927163023959092
# ------------------------
# total invested 1000000
# total return 936671.3755708237
# ROI -6.332862442917634
# bust rate 57.99999999999999
# profit rate 38.0
# wager size 52.17822443905873
# wager count 721.5840615677794
# wager size percentage 0.5217822443905873
# ------------------------
# total invested 1000000
# total return 1035851.5072960291
# ROI 3.585150729602913
# bust rate 37.0
# profit rate 57.99999999999999
# wager size 33.943495559434226
# wager count 650.8764522293567
# wager size percentage 0.3394349555943422
# ------------------------
# total invested 1000000
# total return 983462.0420977494
# ROI -1.653795790225058
# bust rate 0.0
# profit rate 56.00000000000001
# wager size 32.55503524065065
# wager count 43.682963293709655
# wager size percentage 0.32555035240650654
# ------------------------
# total invested 1000000
# total return 1041935.7966697273
# ROI 4.193579666972731
# bust rate 47.0
# profit rate 47.0
# wager size 62.94790646740075
# wager count 543.5534141917187
# wager size percentage 0.6294790646740075
# ------------------------
# total invested 1000000
# total return 884938.7725234417
# ROI -11.50612274765583
# bust rate 50.0
# profit rate 46.0
# wager size 37.454328903235314
# wager count 746.3983078403688
# wager size percentage 0.3745432890323531
# ------------------------
# total invested 1000000
# total return 979409.8599127843
# ROI -2.0590140087215696
# bust rate 6.0
# profit rate 62.0
# wager size 93.14560633895566
# wager count 55.3558132363232
# wager size percentage 0.9314560633895566
# ------------------------
# total invested 1000000
# total return 1015809.6680621555
# ROI 1.5809668062155484
# bust rate 17.0
# profit rate 64.0
# wager size 99.38762247111576
# wager count 118.13327953583298
# wager size percentage 0.9938762247111577
# ------------------------
# total invested 1000000
# total return 881367.5670201564
# ROI -11.863243297984358
# bust rate 33.0
# profit rate 54.0
# wager size 25.924119183089257
# wager count 561.1872561491668
# wager size percentage 0.25924119183089256
# ------------------------
# total invested 1000000
# total return 1105538.4152765528
# ROI 10.553841527655278
# bust rate 22.0
# profit rate 67.0
# wager size 33.846174874294114
# wager count 471.68672166907936
# wager size percentage 0.33846174874294116
# ------------------------
# total invested 1000000
# total return 911737.8375237939
# ROI -8.826216247620607
# bust rate 40.0
# profit rate 51.0
# wager size 21.25266673902865
# wager count 882.6540246748973
# wager size percentage 0.21252666739028653
# ------------------------
# total invested 1000000
# total return 1072196.6162088474
# ROI 7.219661620884738
# bust rate 6.0
# profit rate 76.0
# wager size 78.6050946428123
# wager count 73.94355966168585
# wager size percentage 0.786050946428123
# ------------------------
# total invested 1000000
# total return 1045309.186798378
# ROI 4.530918679837801
# bust rate 26.0
# profit rate 57.99999999999999
# wager size 34.566619297933684
# wager count 474.14634939444977
# wager size percentage 0.3456661929793368
# ------------------------
# total invested 1000000
# total return 1013010.6058635754
# ROI 1.301060586357536
# bust rate 19.0
# profit rate 63.0
# wager size 61.27180886928567
# wager count 191.27215889298495
# wager size percentage 0.6127180886928567
# ------------------------
# total invested 1000000
# total return 1021554.7781169992
# ROI 2.1554778116999196
# bust rate 8.0
# profit rate 68.0
# wager size 99.06664883211016
# wager count 65.56170127559375
# wager size percentage 0.9906664883211016
# ------------------------
# total invested 1000000
# total return 1043437.5525298297
# ROI 4.343755252982967
# bust rate 3.0
# profit rate 74.0
# wager size 55.30736925006938
# wager count 86.078553128349
# wager size percentage 0.5530736925006938
# ------------------------
# total invested 1000000
# total return 1118120.3761569075
# ROI 11.812037615690754
# bust rate 64.0
# profit rate 34.0
# wager size 89.7641724513527
# wager count 776.2073547325824
# wager size percentage 0.897641724513527
# ------------------------
# total invested 1000000
# total return 718242.8781625561
# ROI -28.175712183744388
# bust rate 66.0
# profit rate 28.999999999999996
# wager size 51.56491660562649
# wager count 887.7850062165032
# wager size percentage 0.515649166056265
# ------------------------
# total invested 1000000
# total return 1055476.6338346188
# ROI 5.5476633834618845
# bust rate 62.0
# profit rate 36.0
# wager size 80.74389739253881
# wager count 653.7843486547388
# wager size percentage 0.8074389739253882
# ------------------------
# total invested 1000000
# total return 928019.4982365577
# ROI -7.19805017634423
# bust rate 38.0
# profit rate 52.0
# wager size 35.32106837166281
# wager count 560.1951369044502
# wager size percentage 0.3532106837166281
# ------------------------
# total invested 1000000
# total return 981637.3801168294
# ROI -1.8362619883170586
# bust rate 21.0
# profit rate 66.0
# wager size 14.367745188781075
# wager count 792.4482680056387
# wager size percentage 0.14367745188781075
# ------------------------
# total invested 1000000
# total return 861471.6200818908
# ROI -13.852837991810915
# bust rate 63.0
# profit rate 37.0
# wager size 79.85073071768647
# wager count 455.1216622116353
# wager size percentage 0.7985073071768647
# ------------------------
# total invested 1000000
# total return 1230199.6475768199
# ROI 23.019964757681986
# bust rate 61.0
# profit rate 38.0
# wager size 68.96730402346085
# wager count 809.8332667116633
# wager size percentage 0.6896730402346085
# ------------------------
# total invested 1000000
# total return 931971.2734936448
# ROI -6.802872650635522
# bust rate 52.0
# profit rate 43.0
# wager size 88.2691299443093
# wager count 358.98823471372395
# wager size percentage 0.8826912994430929
# ------------------------
# total invested 1000000
# total return 1151494.0566196796
# ROI 15.149405661967954
# bust rate 28.000000000000004
# profit rate 66.0
# wager size 20.201915021755116
# wager count 910.3838838874148
# wager size percentage 0.20201915021755118
# ------------------------
# total invested 1000000
# total return 942142.9741124249
# ROI -5.785702588757512
# bust rate 72.0
# profit rate 25.0
# wager size 97.27339922346867
# wager count 832.8010244063604
# wager size percentage 0.9727339922346867
# ------------------------
# total invested 1000000
# total return 966931.2445026956
# ROI -3.306875549730438
# bust rate 22.0
# profit rate 62.0
# wager size 10.758013610882557
# wager count 892.180622315397
# wager size percentage 0.10758013610882558
# ------------------------
# total invested 1000000
# total return 1078889.526343088
# ROI 7.888952634308789
# bust rate 6.0
# profit rate 77.0
# wager size 44.28875202266832
# wager count 173.11683629165094
# wager size percentage 0.4428875202266832
# ------------------------
# total invested 1000000
# total return 1097044.648780005
# ROI 9.704464878000506
# bust rate 38.0
# profit rate 60.0
# wager size 97.30476612203478
# wager count 233.4171240417975
# wager size percentage 0.9730476612203477
# ------------------------
# total invested 1000000
# total return 1017698.6942445064
# ROI 1.7698694244506419
# bust rate 17.0
# profit rate 65.0
# wager size 97.7302125630727
# wager count 108.44953388080634
# wager size percentage 0.977302125630727
# ------------------------
# total invested 1000000
# total return 989867.6742952502
# ROI -1.0132325704749792
# bust rate 26.0
# profit rate 59.0
# wager size 17.228899868301866
# wager count 746.1795057511371
# wager size percentage 0.17228899868301867
# ------------------------
# total invested 1000000
# total return 1032255.5263209437
# ROI 3.2255526320943724
# bust rate 38.0
# profit rate 56.99999999999999
# wager size 22.100820576904972
# wager count 938.6506785897532
# wager size percentage 0.22100820576904973
# ------------------------
# total invested 1000000
# total return 1207851.5466335174
# ROI 20.785154663351737
# bust rate 52.0
# profit rate 43.0
# wager size 72.31099895798205
# wager count 665.493562105406
# wager size percentage 0.7231099895798205
# ------------------------
# total invested 1000000
# total return 929930.9981150115
# ROI -7.00690018849885
# bust rate 75.0
# profit rate 24.0
# wager size 91.09652565917182
# wager count 973.3343942289016
# wager size percentage 0.9109652565917182
# ------------------------
# total invested 1000000
# total return 890764.1864873894
# ROI -10.923581351261062
# bust rate 75.0
# profit rate 24.0
# wager size 78.11274603905511
# wager count 939.4843689510354
# wager size percentage 0.781127460390551
# ------------------------
# total invested 1000000
# total return 977236.9818638528
# ROI -2.2763018136147175
# bust rate 66.0
# profit rate 31.0
# wager size 83.90137792399081
# wager count 736.8386932751529
# wager size percentage 0.839013779239908
# ------------------------
# total invested 1000000
# total return 980253.7859705095
# ROI -1.974621402949048
# bust rate 8.0
# profit rate 64.0
# wager size 26.34111899862313
# wager count 222.99251535630395
# wager size percentage 0.2634111899862313
# ------------------------
# total invested 1000000
# total return 898699.0932487673
# ROI -10.130090675123268
# bust rate 56.00000000000001
# profit rate 42.0
# wager size 55.716320452130525
# wager count 634.5161959554976
# wager size percentage 0.5571632045213053
# ------------------------
# total invested 1000000
# total return 757954.0363806214
# ROI -24.204596361937863
# bust rate 70.0
# profit rate 28.999999999999996
# wager size 72.59393694445103
# wager count 614.9342391503434
# wager size percentage 0.7259393694445103
# ------------------------
# total invested 1000000
# total return 963169.716660717
# ROI -3.6830283339282963
# ...
# ROI 5.4255356801202055
# bust rate 44.0
# profit rate 47.0
# wager size 71.53932883438281
# wager count 396.3511836599393
# wager size percentage 0.7153932883438282
# ------------------------
# total invested 1000000
# total return 939986.1571792488
# ROI -6.001384282075125
# bust rate 23.0
# profit rate 61.0
# wager size 94.10136138735102
# wager count 122.70825262733534
# wager size percentage 0.9410136138735102
# ------------------------
# total invested 1000000
# total return 1033505.0814134916
# ROI 3.350508141349163
# bust rate 1.0
# profit rate 68.0
# wager size 17.992175936100782
# wager count 217.38944074960827
# wager size percentage 0.17992175936100782
# ------------------------
# total invested 1000000
# total return 1189205.7793016802
# ROI 18.92057793016802
# bust rate 25.0
# profit rate 68.0
# wager size 29.119091673027086
# wager count 598.8587052193324
# wager size percentage 0.29119091673027087
# ------------------------
# total invested 1000000
# total return 659699.3017435272
# ROI -34.03006982564728
# bust rate 76.0
# profit rate 20.0
# wager size 75.00520523728441
# wager count 925.1317216411568
# wager size percentage 0.7500520523728442
# ------------------------
# total invested 1000000
# total return 1312969.317051596
# ROI 31.296931705159604
# bust rate 57.99999999999999
# profit rate 41.0
# wager size 78.04205032256306
# wager count 836.5595584925616
# wager size percentage 0.7804205032256306
# ------------------------
# total invested 1000000
# total return 892850.4645587769
# ROI -10.714953544122306
# bust rate 41.0
# profit rate 46.0
# wager size 44.151433456384716
# wager count 581.6068324214027
# wager size percentage 0.44151433456384714
# ------------------------
# total invested 1000000
# total return 1157768.1429576497
# ROI 15.776814295764966
# bust rate 44.0
# profit rate 53.0
# wager size 41.70637571250482
# wager count 679.5250092784244
# wager size percentage 0.41706375712504823
# ------------------------
# total invested 1000000
# total return 664862.1898606212
# ROI -33.51378101393788
# bust rate 78.0
# profit rate 22.0
# wager size 84.57991860947364
# wager count 811.3834035686648
# wager size percentage 0.8457991860947364
# ------------------------
# total invested 1000000
# total return 970178.6696254963
# ROI -2.982133037450374
# bust rate 65.0
# profit rate 34.0
# wager size 90.08937452652583
# wager count 604.2328668621511
# wager size percentage 0.9008937452652583
# ------------------------
# total invested 1000000
# total return 886451.8003211325
# ROI -11.354819967886748
# bust rate 55.00000000000001
# profit rate 42.0
# wager size 33.44300966891754
# wager count 915.3148512903998
# wager size percentage 0.3344300966891754
# ------------------------
# total invested 1000000
# total return 1092999.437200914
# ROI 9.29994372009139
# bust rate 5.0
# profit rate 79.0
# wager size 84.26338802123236
# wager count 81.84798007487711
# wager size percentage 0.8426338802123237
# ------------------------
# total invested 1000000
# total return 959781.5769704556
# ROI -4.0218423029544415
# bust rate 4.0
# profit rate 64.0
# wager size 52.914527064343424
# wager count 84.48712917575168
# wager size percentage 0.5291452706434343
# ------------------------
# total invested 1000000
# total return 1040386.7133939151
# ROI 4.0386713393915095
# bust rate 0.0
# profit rate 73.0
# wager size 77.22124931915052
# wager count 39.43035447962012
# wager size percentage 0.7722124931915052
# ------------------------
# total invested 1000000
# total return 954830.131951992
# ROI -4.516986804800795
# bust rate 57.99999999999999
# profit rate 39.0
# wager size 83.04391957188047
# wager count 540.3930646086228
# wager size percentage 0.8304391957188048
# ------------------------
# total invested 1000000
# total return 1016086.0521479166
# ROI 1.6086052147916634
# bust rate 46.0
# profit rate 50.0
# wager size 42.03454041940077
# wager count 641.6659750585221
# wager size percentage 0.4203454041940077
# ------------------------
# total invested 1000000
# total return 916628.4119509334
# ROI -8.337158804906661
# bust rate 35.0
# profit rate 54.0
# wager size 81.18418277723516
# wager count 220.57603610661423
# wager size percentage 0.8118418277723517
# ------------------------
# total invested 1000000
# total return 954516.0313671571
# ROI -4.548396863284288
# bust rate 7.000000000000001
# profit rate 64.0
# wager size 73.71147392753684
# wager count 88.83219604289793
# wager size percentage 0.7371147392753684
# ------------------------
# total invested 1000000
# total return 1054711.9117674828
# ROI 5.471191176748276
# bust rate 38.0
# profit rate 54.0
# wager size 67.54839623603763
# wager count 329.0185383916047
# wager size percentage 0.6754839623603763
# ------------------------
# total invested 1000000
# total return 1025243.4131500692
# ROI 2.524341315006919
# bust rate 32.0
# profit rate 56.00000000000001
# wager size 79.03021855018754
# wager count 250.5027488460622
# wager size percentage 0.7903021855018754
# ------------------------
# total invested 1000000
# total return 985141.8480382175
# ROI -1.4858151961782482
# bust rate 9.0
# profit rate 64.0
# wager size 8.229265238161686
# wager count 809.9753350434986
# wager size percentage 0.08229265238161686
# ------------------------
# total invested 1000000
# total return 1020300.2093402472
# ROI 2.030020934024721
# bust rate 6.0
# profit rate 71.0
# wager size 38.474737682252716
# wager count 170.97576796383652
# wager size percentage 0.3847473768225272
# ------------------------
# total invested 1000000
# total return 911315.0874211568
# ROI -8.868491257884319
# bust rate 65.0
# profit rate 32.0
# wager size 69.02655407802133
# wager count 827.7995681160164
# wager size percentage 0.6902655407802134
# ------------------------
# total invested 1000000
# total return 1037211.279672354
# ROI 3.7211279672353994
# bust rate 31.0
# profit rate 61.0
# wager size 62.0666029807567
# wager count 276.3380212528722
# wager size percentage 0.620666029807567
# ------------------------
# total invested 1000000
# total return 1129193.1981461912
# ROI 12.919319814619119
# bust rate 56.99999999999999
# profit rate 39.0
# wager size 68.12399286987772
# wager count 691.9726192534879
# wager size percentage 0.6812399286987773
# ------------------------
# total invested 1000000
# total return 950478.3936811355
# ROI -4.952160631886451
# bust rate 60.0
# profit rate 37.0
# wager size 74.89309036630621
# wager count 587.6992441011776
# wager size percentage 0.748930903663062
# ------------------------
# total invested 1000000
# total return 864131.052417921
# ROI -13.5868947582079
# bust rate 54.0
# profit rate 41.0
# wager size 65.22644826219856
# wager count 518.65217118546
# wager size percentage 0.6522644826219856
# ------------------------
# total invested 1000000
# total return 1010953.1451208128
# ROI 1.0953145120812813
# bust rate 2.0
# profit rate 65.0
# wager size 35.30167114121653
# wager count 144.21458931877095
# wager size percentage 0.3530167114121653
# ------------------------
# total invested 1000000
# total return 1108903.2538362455
# ROI 10.890325383624551
# bust rate 69.0
# profit rate 31.0
# wager size 78.78463426131609
# wager count 842.8932723822912
# wager size percentage 0.7878463426131608
# ------------------------
# total invested 1000000
# total return 1068260.1731299816
# ROI 6.826017312998162
# bust rate 27.0
# profit rate 64.0
# wager size 54.7788571282424
# wager count 287.51077456749897
# wager size percentage 0.547788571282424
# ------------------------
# total invested 1000000
# total return 682396.4758230948
# ROI -31.76035241769052
# bust rate 66.0
# profit rate 28.000000000000004
# wager size 84.13360628975599
# wager count 432.30790610150075
# wager size percentage 0.8413360628975599
# ------------------------
# total invested 1000000
# total return 924447.8478644075
# ROI -7.555215213559253
# bust rate 36.0
# profit rate 54.0
# wager size 30.361429504050417
# wager count 558.2267597010989
# wager size percentage 0.30361429504050413
# ------------------------
# total invested 1000000
# total return 1011633.1859418526
# ROI 1.163318594185263
# bust rate 1.0
# profit rate 68.0
# wager size 26.906947688870904
# wager count 85.64459488483139
# wager size percentage 0.269069476888709
# ------------------------
# total invested 1000000
# total return 923526.0975575269
# ROI -7.647390244247311
# bust rate 19.0
# profit rate 59.0
# wager size 29.32876156857185
# wager count 317.98629376564054
# wager size percentage 0.2932876156857185
# ------------------------
# total invested 1000000
# total return 1055075.6438165032
# ROI 5.507564381650323
# bust rate 54.0
# profit rate 44.0
# wager size 65.92281616923735
# wager count 603.8916752497005
# wager size percentage 0.6592281616923735
# ------------------------
# total invested 1000000
# total return 1037551.4708632356
# ROI 3.7551470863235648
# bust rate 73.0
# profit rate 26.0
# wager size 92.63337426559316
# wager count 918.6644117153668
# wager size percentage 0.9263337426559316
# ------------------------
# total invested 1000000
# total return 949399.7664711247
# ROI -5.060023352887528
# bust rate 5.0
# profit rate 56.00000000000001
# wager size 69.62789978610765
# wager count 71.18644969794289
# wager size percentage 0.6962789978610765
# ------------------------
# total invested 1000000
# total return 1022889.6866092521
# ROI 2.2889686609252125
# bust rate 46.0
# profit rate 46.0
# wager size 36.404284620848735
# wager count 851.8673187873613
# wager size percentage 0.36404284620848737
# ------------------------
# total invested 1000000
# total return 1052929.1792048162
# ROI 5.2929179204816235
# bust rate 69.0
# profit rate 31.0
# wager size 78.07430985289353
# wager count 822.9764384669454
# wager size percentage 0.7807430985289353
# ------------------------
# total invested 1000000
# total return 958532.6968542197
# ROI -4.1467303145780345
# bust rate 34.0
# profit rate 55.00000000000001
# wager size 38.6249861977392
# wager count 437.9651760800646
# wager size percentage 0.386249861977392
# ------------------------
# total invested 1000000
# total return 1239959.0163342194
# ROI 23.995901633421937
# bust rate 49.0
# profit rate 46.0
# wager size 79.05302896814864
# wager count 552.0042635179169
# wager size percentage 0.7905302896814863
# ------------------------
# total invested 1000000
# total return 1061142.4099325372
# ROI 6.114240993253723
# bust rate 63.0
# profit rate 35.0
# wager size 66.77009032283655
# wager count 746.745162161152
# wager size percentage 0.6677009032283655
# ------------------------
# total invested 1000000
# total return 983102.2405046338
# ROI -1.689775949536625
# bust rate 20.0
# profit rate 64.0
# wager size 11.46537062888606
# wager count 947.6697284291461
# wager size percentage 0.1146537062888606
# ------------------------
# total invested 1000000
# total return 908004.6242951117
# ROI -9.199537570488825
# bust rate 37.0
# profit rate 54.0
# wager size 53.25671809423666
# wager count 332.69363776603757
# wager size percentage 0.5325671809423665
# ------------------------
# total invested 1000000
# total return 1225636.1309957206
# ROI 22.563613099572063
# bust rate 19.0
# profit rate 69.0
# wager size 93.54886894692525
# wager count 194.85383702151773
# wager size percentage 0.9354886894692525
# ------------------------
# total invested 1000000
# total return 1177665.0244680266
# ROI 17.766502446802658
# bust rate 59.0
# profit rate 41.0
# wager size 92.82394172833163
# wager count 565.8416699405161
# wager size percentage 0.9282394172833164
# ------------------------
# total invested 1000000
# total return 811651.917430321
# ROI -18.834808256967904
# bust rate 72.0
# profit rate 26.0
# wager size 93.49676194023955
# wager count 721.4742955785872
# wager size percentage 0.9349676194023955
# ------------------------
# total invested 1000000
# total return 771450.7592727111
# ROI -22.85492407272889
# bust rate 69.0
# profit rate 28.999999999999996
# wager size 85.75244620882981
# wager count 615.6022540674271
# wager size percentage 0.8575244620882981
# ------------------------
# total invested 1000000
# total return 945421.1735194218
# ROI -5.457882648057817
# bust rate 52.0
# profit rate 40.0
# wager size 47.06784763704809
# wager count 705.5871474934378
# wager size percentage 0.4706784763704809
# ------------------------
# total invested 1000000
# total return 1204239.6541196974
# ROI 20.423965411969743
# bust rate 60.0
# profit rate 39.0
# wager size 70.7410789708837
# wager count 811.597932093931
# wager size percentage 0.707410789708837
# ------------------------
# total invested 1000000
# total return 950189.9231156828
# ROI -4.981007688431721
# bust rate 37.0
# profit rate 55.00000000000001
# wager size 94.96155784148569
# wager count 199.04696941337707
# wager size percentage 0.9496155784148568
# ------------------------
# total invested 1000000
# total return 813188.6599137568
# ROI -18.681134008624323
# bust rate 69.0
# profit rate 28.999999999999996
# wager size 98.30792661327541
# wager count 554.2184754107673
# wager size percentage 0.9830792661327541
# ------------------------
# total invested 1000000
# total return 925466.0035679251
# ROI -7.453399643207492
# bust rate 30.0
# profit rate 56.99999999999999
# wager size 82.51892555386804
# wager count 187.56253826481955
# wager size percentage 0.8251892555386805
# ------------------------
# total invested 1000000
# total return 1209054.9326834974
# ROI 20.905493268349744
# bust rate 65.0
# profit rate 34.0
# wager size 76.77335725862734
# wager count 900.9923788358348
# wager size percentage 0.7677335725862734
# ------------------------
# total invested 1000000
# total return 981701.208303758
# ROI -1.8298791696242056
# bust rate 6.0
# profit rate 61.0
# wager size 97.24670685993868
# wager count 56.088358488358445
# wager size percentage 0.9724670685993869
# ------------------------
# total invested 1000000
# total return 1053997.406082073
# ROI 5.399740608207299
# bust rate 31.0
# profit rate 60.0
# wager size 27.671362264455535
# wager count 731.3654935303459
# wager size percentage 0.27671362264455535
# ------------------------
# total invested 1000000
# total return 939049.6996608579
# ROI -6.09503003391421
# bust rate 51.0
# profit rate 44.0
# wager size 73.1712966569499
# wager count 439.48791245690035
# wager size percentage 0.731712966569499
# ------------------------
# total invested 1000000
# total return 1192280.1130839847
# ROI 19.22801130839847
# bust rate 42.0
# profit rate 55.00000000000001
# wager size 35.08798506366365
# wager count 821.614763255037
# wager size percentage 0.3508798506366365
# ------------------------
# total invested 1000000
# total return 1012222.8646911442
# ROI 1.2222864691144204
# bust rate 26.0
# profit rate 63.0
# wager size 60.83274606901066
# wager count 234.2663976801508
# wager size percentage 0.6083274606901067
# ------------------------
# total invested 1000000
# total return 1232456.9274380514
# ROI 23.245692743805144
# bust rate 44.0
# profit rate 54.0
# wager size 38.289708436290354
# wager count 858.9654409969297
# wager size percentage 0.38289708436290354
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 120
#     117 wagerSizePercent = (wagerSize/startingFunds)*100.00
#     119 while counter <= daSampSize:
# --> 120     dAlembert(startingFunds, wagerSize, wagerCount)
#     121     counter += 1
#     123 ROI = ret - (daSampSize*startingFunds)
#
# Cell In[26], line 74, in dAlembert(funds, initial_wager, wager_count)
#      70     wager = value
#      72 #print('lost last wager', wager, 'value', value)
# ---> 74 if rollDice():
#      75     value += wager
#      76     previousWager = 'win'
#
# Cell In[26], line 22, in rollDice()
#      21 def rollDice():
# ---> 22     roll = random.randint(1, 100)
#      24     if roll <= 50:
#      25         #print(roll,'roll was 1-50, you lose.')
#      26         return False
#
# File /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/random.py:336, in Random.randint(self, a, b)
#     332 def randint(self, a, b):
#     333     """Return random integer in range [a, b], including both end points.
#     334     """
# --> 336     return self.randrange(a, b+1)
#
# File /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/random.py:318, in Random.randrange(self, start, stop, step)
#     316 if istep == 1:
#     317     if width > 0:
# --> 318         return istart + self._randbelow(width)
#     319     raise ValueError(f"empty range in randrange({start}, {stop})")
#     321 # Non-unit step argument supplied.
#
# File /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/random.py:246, in Random._randbelow_with_getrandbits(self, n)
#     243 "Return a random int in the range [0,n).  Defined for n > 0."
#     245 getrandbits = self.getrandbits
# --> 246 k = n.bit_length()
#     247 r = getrandbits(k)  # 0 <= r < 2**k
#     248 while r >= n:
#
# KeyboardInterrupt:
